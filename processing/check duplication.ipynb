# %% [markdown]
# ## Check duplication
# this is my first juptyer code.

# %% [markdown]
# df_path = '/Users/gelad/Personality-based-commerce/results/data/filter_description/10475_2018-08-08 14:51:48.csv'
# import pandas as pd
# df = pd.read_csv(df_path)

# %%
df
# Out:
#             item_id                                        description  \
# 0      372071768698  description description shipping description :...
# 1      182917764305  description : : : e : ca 4 1 cm x 3 3 cm x 1 5...
# 2      391920151847  store category sign up now ! you may also like...
# 3      152673009279  product cher ( set ) unsere sch st r die gr e ...
# 4      112724124314  % brand new and hight quality easy and conveni...
# 5      382277654251  similar : camera and tripod are not included p...
# 6      372032390364  description description shipping description :...
# 7      232419618550  samurai ninja umbrella mit katana ( ) : ca 97 ...
# 8      111840009966  hand made aby switch box true bypass amp / gui...
# 9      282556620130  metal heavy duty camera tripod qr quick releas...
# 10     132442213084  add to my favorite sellers mon to sat customer...
# 11     291646418165  store category sign up now ! you may also like...
# ...

# %%
df.shape
# Out:
# (10475, 90)

# %%
df_without_dup = df.drop_duplicates(subset=None, keep='first', inplace=False)
df.shape
# Out:
# (10475, 90)

# %%
df_without_dup.shape
# Out:
# (9693, 90)
